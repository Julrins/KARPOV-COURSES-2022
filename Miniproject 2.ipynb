# %%
import pandas as pd

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
user_data = pd.read_csv('/mnt/HC_Volume_18315164/home-jupyter/jupyter-a-tutov/3_user_data.csv')

# %%
logs = pd.read_csv('/mnt/HC_Volume_18315164/home-jupyter/jupyter-a-tutov/3_logs.csv')

# %%
logs
# Out:
#       client  success  platform        time
# 0      40177     True     phone  1585412212
# 1      61468     True     phone  1585425658
# 2      35604    False     phone  1585459894
# 3       9961     True     phone  1585400189
# 4      10931     True  computer  1585468629
# ...      ...      ...       ...         ...
# 4495   64496    False  computer  1585459072
# 4496   73299     True     phone  1585458370
# 4497    8967     True     phone  1585465121
# 4498   52880    False     phone  1585455362
# 4499   40921     True     phone  1585437692
#
# [4500 rows x 4 columns]

# %%
user_data
# Out:
#       client  premium  age
# 0      46346    False   58
# 1       4391    False   55
# 2      27372    False   64
# 3      11989    False   44
# 4      60664    False   49
# ...      ...      ...  ...
# 2949   19411    False   29
# 2950   61579    False   50
# 2951   61221     True   64
# 2952   29863    False   46
# 2953   78499    False   36
#
# [2954 rows x 3 columns]

# %%
logs.platform.unique ()
# Out:
# array(['phone', 'computer', 'tablet'], dtype=object)

# %%
logs1 = logs.query('success == True').groupby(['client'], as_index = False).agg({'client' : 'count'}).sort_values('client')

# %%
logs1
# Out:
#       client
# 0          1
# 1882       1
# 1883       1
# 1884       1
# 1885       1
# ...      ...
# 810       41
# 1487      41
# 1020      41
# 2626      41
# 1759      41
#
# [2845 rows x 1 columns]

# %%
logs1.query('client == 41')
# Out:
#       client
# 332       41
# 2231      41
# 1758      41
# 2345      41
# 810       41
# 1487      41
# 1020      41
# 2626      41
# 1759      41

# %%
sns.countplot(logs['platform'])
# Out:
# /opt/tljh/user/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
ndf = logs.merge(user_data)

# %%
ndf
# Out:
#       client  success  platform        time  premium  age
# 0      61468     True     phone  1585425658    False   25
# 1      61468     True  computer  1585460504    False   25
# 2      61468     True  computer  1585430291    False   25
# 3      61468     True  computer  1585444317    False   25
# 4      61468     True     phone  1585441266    False   25
# ...      ...      ...       ...         ...      ...  ...
# 3434   62438    False     phone  1585479041    False   36
# 3435   95152     True  computer  1585420263    False   67
# 3436   64496    False  computer  1585459072    False   66
# 3437    8967     True     phone  1585465121    False   33
# 3438   40921     True     phone  1585437692    False   45
#
# [3439 rows x 6 columns]

# %%
pndf = ndf.query('premium == True')

# %%
pndf
# Out:
#       client  success  platform        time  premium  age
# 42     35604    False     phone  1585459894     True   65
# 49     11983     True     phone  1585459511     True   68
# 52     99308     True  computer  1585409409     True   38
# 59     49625    False     phone  1585447789     True   65
# 64     53978     True  computer  1585408637     True   46
# ...      ...      ...       ...         ...      ...  ...
# 3376   20278     True  computer  1585456706     True   65
# 3399   78455     True     phone  1585459854     True   23
# 3401   57026     True  computer  1585438120     True   62
# 3418    2864     True     phone  1585459818     True   41
# 3431   72908     True     phone  1585416689     True   66
#
# [420 rows x 6 columns]

# %%
sns.countplot(pndf['platform'])
# Out:
# /opt/tljh/user/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
ndf
# Out:
#       client  success  platform        time  premium  age
# 0      61468     True     phone  1585425658    False   25
# 1      61468     True  computer  1585460504    False   25
# 2      61468     True  computer  1585430291    False   25
# 3      61468     True  computer  1585444317    False   25
# 4      61468     True     phone  1585441266    False   25
# ...      ...      ...       ...         ...      ...  ...
# 3434   62438    False     phone  1585479041    False   36
# 3435   95152     True  computer  1585420263    False   67
# 3436   64496    False  computer  1585459072    False   66
# 3437    8967     True     phone  1585465121    False   33
# 3438   40921     True     phone  1585437692    False   45
#
# [3439 rows x 6 columns]

# %%
sns.displot(ndf.age)
sns.histplot(ndf.premium)
# Out:
# <string>:6: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <string>:6: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.

# %%
ndfl = ndf.query('platform == "computer" ')

# %%
ndfl
# Out:
#       client  success  platform        time  premium  age
# 1      61468     True  computer  1585460504    False   25
# 2      61468     True  computer  1585430291    False   25
# 3      61468     True  computer  1585444317    False   25
# 7      61468     True  computer  1585416826    False   25
# 11     61468     True  computer  1585428874    False   25
# ...      ...      ...       ...         ...      ...  ...
# 3428   62610    False  computer  1585417660    False   60
# 3432   85769     True  computer  1585447052    False   46
# 3433   81031     True  computer  1585401631    False   45
# 3435   95152     True  computer  1585420263    False   67
# 3436   64496    False  computer  1585459072    False   66
#
# [1140 rows x 6 columns]

# %%
plt.figure(figsize=(16, 12))
sns.countplot(ndfl['age'])
# Out:
# /opt/tljh/user/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
