# %%
# Проект e-commerce: вариант 1

# %%
import pandas as pd

# %%
items = pd.read_csv("/mnt/HC_Volume_18315164/home-jupyter/jupyter-a-tutov/olist_order_items_dataset.csv")
items
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 112645  fffc94f6ce00a00581880bf54a75a037              1
# 112646  fffcd46ef2263f404302a634eb57f7eb              1
# 112647  fffce4705a9662cd70adb13d4a31832d              1
# 112648  fffe18544ffabc95dfada21779c9644f              1
# 112649  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %%
orders = pd.read_csv("/mnt/HC_Volume_18315164/home-jupyter/jupyter-a-tutov/olist_orders_dataset.csv")
orders
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 99436  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 99437  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 99438  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 99439  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 99440  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#       order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
customers = pd.read_csv("/mnt/HC_Volume_18315164/home-jupyter/jupyter-a-tutov/olist_customers_dataset.csv")
customers
# Out:
#                             customer_id                customer_unique_id  \
# 0      06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1      18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2      4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3      b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4      4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# ...                                 ...                               ...
# 99436  17ddf5dd5d51696bb3d7c6291687be6f  1a29b476fee25c95fbafc67c5ac95cf8
# 99437  e7b71a9017aa05c9a7fd292d714858e8  d52a67c98be1cf6a5c84435bd38d095d
# 99438  5e28dfe12db7fb50a4b2f691faecea5e  e9f50caf99f032f0bf3c55141f019d99
# 99439  56b18e2166679b8a959d72dd06da27f9  73c2643a0a458b49f58cea58833b192e
# 99440  274fa6071e5e17fe303b9748641082c8  84732c5050c01db9b23e19ba39899398
#
#        customer_zip_code_prefix          customer_city customer_state
# ...

# %%
### ЗАДАНИЕ 1 (Сколько у нас пользователей, которые совершили покупку только один раз?)

# %%
# ЗАМЕРДЖИМ ТАБЛИЦЫ (ЗАМЕТИМ, ЧТО ВО 2 И 3 ТАБЛ. ОДИНАКОВОЕ ЧИСЛО СТРОК)

# %%
order_AND_items = pd.merge(orders, items, on='order_id')
order_AND_items
# Out:
#                                 order_id                       customer_id  \
# 0       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1       53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2       47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3       949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4       ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                  ...                               ...
# 112645  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 112646  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 112647  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 112648  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 112649  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#        order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
# ДАЛЬШЕ НАЙДЕМ УНИКАЛЬНЫХ ПОЛЬЗОВАТЕЛЕЙ (Т.Е ТЕХ, КТО СОВЕРШИЛ ПОКУПКУ ЕДИНОЖДЫ)

# %%
uniq_customers = order_AND_items['customer_id'].value_counts()
count = sum(uniq_customers == 1)
count
# Out:
# 88863

# %%
# ЗАДАНИЕ 2 (Сколько заказов в месяц в среднем не доставляется по разным причинам (вывести детализацию по причинам)?)

# %%
# ТАБЛИЦЫ ЗАМЕРЖЕНЫ, НО Т.К. ПРИДЕТСЯ РАБОТАТЬ С ДАННЫМИ, ТО ПОКРУТИМ ФОРМАТЫ

# %%
order_AND_items['order_purchase_timestamp'] = pd.to_datetime(order_AND_items['order_purchase_timestamp'])
order_AND_items['month'] = order_AND_items['order_purchase_timestamp'].dt.month

# %%
order_AND_items
# Out:
#                                 order_id                       customer_id  \
# 0       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1       53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2       47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3       949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4       ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                  ...                               ...
# 112645  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 112646  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 112647  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 112648  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 112649  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#        order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
order_AND_items_group = order_AND_items.groupby(['month', 'order_status'])['order_id'].count().reset_index()

# %%
order_AND_items_group
# Out:
#     month order_status  order_id
# 0       1     canceled        37
# 1       1    delivered      8950
# 2       1     invoiced        30
# 3       1   processing        45
# 4       1      shipped       101
# ..    ...          ...       ...
# 58     12     canceled         8
# 59     12    delivered      6188
# 60     12     invoiced        18
# 61     12   processing        36
# 62     12      shipped        59
#
# [63 rows x 3 columns]

# %%
canceled = order_AND_items_group.query("order_status == 'canceled'")
canceled.order_status
# Out:
#     month order_status  order_id
# 0       1     canceled        37
# 6       2     canceled        90
# 11      3     canceled        47
# 17      4     canceled        42
# 22      5     canceled        57
# 27      6     canceled        30
# 32      7     canceled        79
# 37      8     canceled        60
# 42      9     canceled        17
# 47     10     canceled        36
# 53     11     canceled        39
# 58     12     canceled         8

# %%
avg_canceled = canceled['order_id'].mean()
round(avg_canceled, 3)
# Out:
# 45.167

# %%
# ЗАДАНИЕ 3 (По каждому товару определить, в какой день недели товар чаще всего покупается.)

# %%
# ЗАМЕРДЖИМ ВСЕ ТАБЛИЦЫ

# %%
full = pd.merge(orders, items, on='order_id')
full = pd.merge(full, customers, on='customer_id')

# %%
full
# Out:
#                                 order_id                       customer_id  \
# 0       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1       53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2       47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3       949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4       ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                  ...                               ...
# 112645  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 112646  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 112647  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 112648  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 112649  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#        order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
full['order_purchase_timestamp'] = pd.to_datetime(full['order_purchase_timestamp'])
full['day_of_week'] = full['order_purchase_timestamp'].dt.dayofweek

# %%
full
# Out:
#                                 order_id                       customer_id  \
# 0       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1       53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2       47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3       949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4       ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                  ...                               ...
# 112645  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 112646  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 112647  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 112648  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 112649  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#        order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
# проведем группировку и посчитаем заказы по дням

# %%
grouped = full.groupby(['product_id', 'day_of_week'])['order_id'].count().reset_index()

# %%
grouped
# Out:
#                              product_id  day_of_week  order_id
# 0      00066f42aeeb9f3007548bb9d3f33c38            6         1
# 1      00088930e925c41fd95ebfe695fd2655            1         1
# 2      0009406fd7479715e4bef61dd91f2462            3         1
# 3      000b8f95fcb9e0096488278317764d19            2         1
# 4      000b8f95fcb9e0096488278317764d19            4         1
# ...                                 ...          ...       ...
# 61225  fffdb2d0ec8d6a61f0a0a0db3f25b441            1         2
# 61226  fffdb2d0ec8d6a61f0a0a0db3f25b441            3         1
# 61227  fffdb2d0ec8d6a61f0a0a0db3f25b441            4         1
# 61228  fffdb2d0ec8d6a61f0a0a0db3f25b441            6         1
# 61229  fffe9eeff12fcbd74a2f2b007dde0c58            2         1
#
# [61230 rows x 3 columns]

# %%
# поставим наиболее покупательный день для каждого айдишника товара
popular = grouped.loc[grouped.groupby('product_id')['order_id'].idxmax()]
popular
# Out:
#                              product_id  day_of_week  order_id
# 0      00066f42aeeb9f3007548bb9d3f33c38            6         1
# 1      00088930e925c41fd95ebfe695fd2655            1         1
# 2      0009406fd7479715e4bef61dd91f2462            3         1
# 3      000b8f95fcb9e0096488278317764d19            2         1
# 5      000d9be29b5207b54e86aa1b1ac54872            1         1
# ...                                 ...          ...       ...
# 61221  fff6177642830a9a94a0f2cba5e476d1            5         1
# 61223  fff81cc3158d2725c0655ab9ba0f712c            0         1
# 61224  fff9553ac224cec9d15d49f5a263411f            4         1
# 61225  fffdb2d0ec8d6a61f0a0a0db3f25b441            1         2
# 61229  fffe9eeff12fcbd74a2f2b007dde0c58            2         1
#
# [32951 rows x 3 columns]

# %%
# ЗАДАНИЕ 4 (Сколько у каждого из пользователей в среднем покупок в неделю (по месяцам)?)

# %%
order_AND_items
# Out:
#                                 order_id                       customer_id  \
# 0       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1       53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2       47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3       949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4       ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                  ...                               ...
# 112645  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 112646  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 112647  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 112648  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 112649  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#        order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
# сгруппируем данные по месяцам и пользователям

# %%
group_mon_us = order_AND_items.groupby(['customer_id', 'month'])['order_id'].count().reset_index()
group_mon_us
# Out:
#                             customer_id  month  order_id
# 0      00012a2ce6f8dcda20d059ce98491703     11         1
# 1      000161a058600d5901f007fab4c27140      7         1
# 2      0001fd6190edaaf884bcaf3d49edf079      2         1
# 3      0002414f95344307404f0ace7a26f1d5      8         1
# 4      000379cdec625522490c315e70c7a9fb      4         1
# ...                                 ...    ...       ...
# 98661  fffcb937e9dd47a13f05ecb8290f4d3e      3         1
# 98662  fffecc9f79fd8c764f843e9951b11341      3         1
# 98663  fffeda5b6d849fbd39689bb92087f431      5         1
# 98664  ffff42319e9b2d713724ae527742af25      6         1
# 98665  ffffa3172527f765de70084a7e53aae8      9         2
#
# [98666 rows x 3 columns]

# %%
# с помощью лямбда - функции посчитаем кол-во недель в месяце

# %%
import numpy as np

# %%
# попробовал так, но не работает. weeks_in_month = group_mon_us['month'].apply(lambda x: np.ceil((x.end_time - x.start_time).days / 7))

# %%
weeks_in_month = group_mon_us['month'].apply(lambda x: x.to_timestamp().end_time.to_period('W') - x.to_timestamp().start_time.to_period('W') + 1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-75-517f76032c9d> in <module>
# ----> 1 weeks_in_month = group_mon_us['month'].apply(lambda x: x.to_timestamp().end_time.to_period('W') - x.to_timestamp().start_time.to_period('W') + 1)
#
# /opt/tljh/user/lib/python3.7/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    4198             else:
#    4199                 values = self.astype(object)._values
# -> 4200                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4201
#    4202         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-75-517f76032c9d> in <lambda>(x)
# ----> 1 weeks_in_month = group_mon_us['month'].apply(lambda x: x.to_timestamp().end_time.to_period('W') - x.to_timestamp().start_time.to_period('W') + 1)
#
# ...

# %%
group_mon_us['month'] = pd.to_datetime(group_mon_us['month'], format='%Y-%m').dt.to_period('M')

# %%
group_mon_us
# Out:
#                             customer_id    month  order_id
# 0      00012a2ce6f8dcda20d059ce98491703  1970-01         1
# 1      000161a058600d5901f007fab4c27140  1970-01         1
# 2      0001fd6190edaaf884bcaf3d49edf079  1970-01         1
# 3      0002414f95344307404f0ace7a26f1d5  1970-01         1
# 4      000379cdec625522490c315e70c7a9fb  1970-01         1
# ...                                 ...      ...       ...
# 98661  fffcb937e9dd47a13f05ecb8290f4d3e  1970-01         1
# 98662  fffecc9f79fd8c764f843e9951b11341  1970-01         1
# 98663  fffeda5b6d849fbd39689bb92087f431  1970-01         1
# 98664  ffff42319e9b2d713724ae527742af25  1970-01         1
# 98665  ffffa3172527f765de70084a7e53aae8  1970-01         2
#
# [98666 rows x 3 columns]

# %%
weeks_in_month = group_mon_us['month'].apply(lambda x: x.to_timestamp().end_time.to_period('W') - x.to_timestamp().start_time.to_period('W') + 1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /opt/tljh/user/lib/python3.7/site-packages/pandas/core/indexes/extension.py in map(self, mapper, na_action)
#     256         try:
# --> 257             result = mapper(self)
#     258
#
# <ipython-input-82-517f76032c9d> in <lambda>(x)
# ----> 1 weeks_in_month = group_mon_us['month'].apply(lambda x: x.to_timestamp().end_time.to_period('W') - x.to_timestamp().start_time.to_period('W') + 1)
#
# AttributeError: 'DatetimeIndex' object has no attribute 'end_time'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-82-517f76032c9d> in <module>
# ----> 1 weeks_in_month = group_mon_us['month'].apply(lambda x: x.to_timestamp().end_time.to_period('W') - x.to_timestamp().start_time.to_period('W') + 1)
#
# ...

# %%
# в общем, не разробрался со временем, но идея следующая:

# %%
group_mon_us['avg_orders_per_week'] = weeks_in_month['order_id'] / weeks_in_month
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-84-74c7674d5a8d> in <module>
# ----> 1 group_mon_us['avg_orders_per_week'] = weeks_in_month['order_id'] / weeks_in_month
#
# NameError: name 'weeks_in_month' is not defined

# %%
# по итогу получим ответ

# %%
# ЗАДАНИЕ 5 (Используя pandas, проведи когортный анализ пользователей. В период с января по декабрь выяви когорту с самым высоким retention на 3й месяц)

# %%
full
# Out:
#                                 order_id                       customer_id  \
# 0       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1       53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2       47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3       949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4       ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                  ...                               ...
# 112645  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 112646  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 112647  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 112648  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 112649  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#        order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
full['order_purchase_timestamp'] = pd.to_datetime(full['order_purchase_timestamp'])
full['order_approved_at'] = pd.to_datetime(full['order_approved_at'])
full['order_delivered_carrier_date'] = pd.to_datetime(full['order_delivered_carrier_date'])
full['order_delivered_customer_date'] = pd.to_datetime(full['order_delivered_customer_date'])
full['order_estimated_delivery_date'] = pd.to_datetime(full['order_estimated_delivery_date'])

# %%
full
# Out:
#                                 order_id                       customer_id  \
# 0       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1       53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2       47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3       949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4       ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                  ...                               ...
# 112645  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 112646  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 112647  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 112648  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 112649  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#        order_status order_purchase_timestamp   order_approved_at  \
# ...

# %%
full['first_purchase_month'] = full.groupby('customer_unique_id')['order_purchase_timestamp'].transform('min').dt.to_period('M')

# %%
# вычислив первый месяц покупки, отберем данные в период с декабря по январь

# %%
full = full[(full['order_purchase_timestamp'].dt.year == 2017) | (full['order_purchase_timestamp'].dt.year == 2018)]

# %%
full
# Out:
#                                 order_id                       customer_id  \
# 0       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1       53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2       47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3       949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4       ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                  ...                               ...
# 112645  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 112646  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 112647  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 112648  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 112649  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#        order_status order_purchase_timestamp   order_approved_at  \
# ...

# %%
cohorts = full.groupby(['first_purchase_month', pd.Grouper(key='order_purchase_timestamp', freq='1M')])['customer_unique_id'].nunique()
cohorts_retention = cohorts.unstack().divide(cohorts.groupby('first_purchase_month').first(), axis=0)
retention_3rd_month = cohorts_retention.iloc[:, 2]
retention_3rd_month
# Out:
# first_purchase_month
# 2016-10         NaN
# 2016-12         NaN
# 2017-01    0.002653
# 2017-02    0.002346
# 2017-03    1.000000
# 2017-04         NaN
# 2017-05         NaN
# 2017-06         NaN
# 2017-07         NaN
# 2017-08         NaN
# 2017-09         NaN
# 2017-10         NaN
# 2017-11         NaN
# 2017-12         NaN
# 2018-01         NaN
# 2018-02         NaN
# 2018-03         NaN
# 2018-04         NaN
# 2018-05         NaN
# 2018-06         NaN
# 2018-07         NaN
# 2018-08         NaN
# Freq: M, Name: 2017-03-31 00:00:00, dtype: float64

# %%
max_retention_cohort = retention_3rd_month.idxmax()
max_retention_cohort
# Out:
# Period('2017-03', 'M')

# %%
# ЗАДАНИЕ 6 (Используя python, построй RFM-сегментацию пользователей, чтобы качественно оценить свою аудиторию.)

# %%
import datetime
current_date  = datetime.datetime.now()

# %%
RFM = full.groupby('customer_unique_id').agg({
    'order_purchase_timestamp': lambda x: (current_date - x.max()).days,
    'order_id': 'nunique',
    'price': 'sum'
})
RFM.columns = ['recency', 'frequency', 'monetary']

# %%
RFM
# Out:
#                                   recency  frequency  monetary
# customer_unique_id
# 0000366f3b9a7992bf8c76cfdf3221e2     1802          1    129.90
# 0000b849f77a49e4a4ce2b2a4ca5be3f     1805          1     18.90
# 0000f46a3911fa3c0805444483337064     2227          1     69.00
# 0000f6ccb0745a6a4b88665a16c9f078     2011          1     25.99
# 0004aac84e0df4da2b147fca70cf8255     1978          1    180.00
# ...                                   ...        ...       ...
# fffcf5a5ff07b0908bd4e2dbc735a684     2137          1   1570.00
# fffea47cd6d3cc0a88bd621562a9d061     1952          1     64.89
# ffff371b4d645b6ecea244b27531430a     2258          1     89.90
# ffff5962728ec6157033ef9805bacc48     1809          1    115.00
# ffffd2657e2aad2907e67c3e9daecbeb     2174          1     56.99
#
# [95121 rows x 3 columns]

# %%
# ПОРАБОТАЕМ С KMeans ДЛЯ КЛАСТЕРИЗАЦИИИ

# %%
from sklearn.cluster import KMeans

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
RFM_scaler = scaler.fit_transform(RFM)

# %%
# после нормализации необходимо определить оптимальное кол-во кластеров

# %%
from sklearn.metrics import silhouette_score

# %%
scores = []
for k in range(2, 11):
    kmeans = KMeans(n_clusters=k, random_state=1)
    kmeans.fit(rfm_scaled)
    score = silhouette_score(rfm_scaled, kmeans.labels_)
    scores.append(score)

# %%
kmeans = KMeans(n_clusters=4, random_state=1)
kmeans.fit(rfm_scaled)
labels = kmeans.labels_

# %%
import matplotlib.pyplot as plt

# %%
RFM['cluster'] = labels
cluster_means = RFM.groupby('cluster').mean()

# %%
fig, axs = plt.subplots(1, 3, figsize=(15, 5))
axs[0].bar(cluster_means.index, cluster_means['recency'])
axs[0].set_title('Recency')
axs[1].bar(cluster_means.index, cluster_means['frequency'])
axs[1].set_title('Frequency')
axs[2].bar(cluster_means.index, cluster_means['monetary'])
axs[2].set_title('Monetary')
plt.show()

# %%
# ВЫВОД ПО КЛАСТЕРУ 0:
# recency > 1750 и < 2000 дней, frequency от 0 до 1 покупок, monetary < 200.
# слишком низкие затраты и средняя покупаемость.
# у всех кластеров примерно одинаковые временные границы

# %%
# ВЫВОД ПО КЛАСТЕРУ 1:
# recency > 1750 и < 2000 дней, frequency от 0 до 2 покупок, monetary < 200.
# средние затраты и самая высокая покупаемость.
# у всех кластеров примерно одинаковые временные границы

# %%
# ВЫВОД ПО КЛАСТЕРУ 2:
# recency > 1750 дней (самое большое значение), frequency от 0 до 1 покупок, monetary < 200 (как и у кластера 0).
# слишком низкие затраты и средняя покупаемость.
# у всех кластеров примерно одинаковые временные границы

# %%
# ВЫВОД ПО КЛАСТЕРУ 3:
# recency > 1750 и < 2000 дней, frequency от 0 до 1 покупок, monetary < 200 (самая высокая).
# высокие затраты и средняя покупаемость.
# у всех кластеров примерно одинаковые временные границы

# %%
# кластеры 1 и 3 являются наиболее платежеспособными, клиенты этого кластера совершают покупки регулярно и тратятся
